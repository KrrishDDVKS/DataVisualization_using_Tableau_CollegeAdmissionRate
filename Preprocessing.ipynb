# %%
import numpy as np
import pandas as pd
import math

# %%
df=pd.read_csv("MERGED2018-19.csv")
df=df.dropna(subset=['ADM_RATE'])
x=df['ADM_RATE']
y=df['LATITUDE']
z=df['LONGITUDE']
df.head()
# Out:
# C:\Users\Desaboina Krishna Sa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1725,1726,1727,1728,1815,1818,1823,1824,1830,1831,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1910,1911,1912,1913,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#      UNITID    OPEID  OPEID6                              INSTNM       CITY  \
# 772  427308  3181400   31814         Merkaz Bnos-Business School   Brooklyn
# 790  481058  4157800   41578            Grace Mission University  Fullerton
# 802  192509  2093700   20937      Long Island Business Institute   Flushing
# 805  491491  4238300   42383                    Oikos University    Oakland
# 813  110404   113100    1131  California Institute of Technology   Pasadena
#
# ...

# %%
df=df.drop(columns='UNITID')
df=df.drop(columns='OPEID')
df=df.drop(columns='OPEID6')
df=df.drop(columns='INSTURL')
df=df.drop(columns='NPCURL')
df=df.drop(columns='SCH_DEG')
df=df.drop(columns='LOCALE2')
df=df.drop(columns='RELAFFIL')
df=df.drop(columns='ADM_RATE_ALL')
df=df.drop(columns='SATVR25')
df=df.drop(columns='SATMT25')
df=df.drop(columns='SATWR25')
df=df.drop(columns='SATVRMID')
df=df.drop(columns='SATMTMID')
df=df.drop(columns='SATWRMID')
df=df.drop(columns='ACTCM25')
df=df.iloc[ :, 0:14]
df['LOCALE']=df['LOCALE'].replace(np.nan,0)
df['LOCALE']=df['LOCALE'].replace(-3,0)
df['ADM_RATE']=x
df
# Out:
#                                       INSTNM       CITY STABBR         ZIP  \
# 772              Merkaz Bnos-Business School   Brooklyn     NY       11214
# 790                 Grace Mission University  Fullerton     CA  92833-3860
# 802           Long Island Business Institute   Flushing     NY  11354-5577
# 805                         Oikos University    Oakland     CA  94621-2041
# 813       California Institute of Technology   Pasadena     CA       91125
# ...                                      ...        ...    ...         ...
# 6768           Yeshiva Gedolah Keren Hatorah   Lakewood     NJ  08701-1239
# 6774            Yeshiva Gedolah of Cliffwood    Keyport     NJ  07735-5105
# 6780                     Seminary Bnos Chaim   Lakewood     NJ  08701-2336
# 6786       Yeshiva Gedola Tiferes Yerachmiel   Lakewood     NJ  08701-0000
# 6795  EDP University of Puerto Rico-Villalba   Villalba     PR  00766-2353
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2006 entries, 772 to 6795
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   INSTNM        2006 non-null   object
#  1   CITY          2006 non-null   object
#  2   STABBR        2006 non-null   object
#  3   ZIP           2006 non-null   object
#  4   ACCREDAGENCY  1983 non-null   object
#  5   HCM2          2006 non-null   int64
#  6   MAIN          2006 non-null   int64
#  7   NUMBRANCH     2006 non-null   int64
#  8   PREDDEG       2006 non-null   int64
#  9   HIGHDEG       2006 non-null   int64
#  10  CONTROL       2006 non-null   int64
#  11  ST_FIPS       2006 non-null   int64
#  12  REGION        2006 non-null   int64
#  13  LOCALE        2006 non-null   float64
#  14  ADM_RATE      2006 non-null   float64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 250.8+ KB

# %%
def f(t,S,T):
    a=[]
    b=[]
    for i in df[t]:
        j=int(i//10)
        b.append(j)
        k=int(i%10)
        if j>2:
            a.append(S[k])
        else:
            a.append(T[k])
    df['TYPE']=a
    df['PLACE']=b

# %%
def fn(t,S):
    a=[]
    for i in df[t]:
        a.append(S[i])
    df[t]=a

# %%
S=['N','Alabama','Alaska','N','Arizona','Arkansas','California','N','Colorado','Connecticut','Delaware','District of Columbia','Florida','Georgia','N','Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon','Pennsylvania','N','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','N','Washington','West Virginia','Wisconsin','Wyoming','N','N','N','American Samoa','N','N','N','Federated States of Micronesia','N','Guam','N','N','Northern Mariana Islands','Palau','N','Puerto Rico','N','N','N','N','N','Virgin Islands']
t='ST_FIPS'
fn(t,S)
S=['Not main campus','Main campus']
t='MAIN'
fn(t,S)
S=['Not classified','Predominantly certificate-degree granting',"Predominantly associate's-degree granting","Predominantly bachelor's-degree granting","Entirely graduate-degree granting"]
t='PREDDEG'
fn(t,S)
S=['Non-degree-granting','Certificate degree',"Associate degree","Bachelor's degree","Graduate degree"]
t='HIGHDEG'
fn(t,S)
S=['N','Public','Private nonprofit','Private for-profit']
t='CONTROL'
fn(t,S)
S=['U.S. Service Schools','New England','Mid East','Great Lakes','Plains','Southeast','Southwest','Rocky Mountains','Far West','Outlying Areas']
t='REGION'
fn(t,S)
S=['N','Fringe','Distant','Remote']
T=['N','Large','Midsize','Small']
t='LOCALE'
f(t,S,T)
S=['N','City','Suburb','Town','Rural']
t='PLACE'
fn(t,S)
df=df.drop(columns='LOCALE')
df
# Out:
#                                       INSTNM       CITY STABBR         ZIP  \
# 772              Merkaz Bnos-Business School   Brooklyn     NY       11214
# 790                 Grace Mission University  Fullerton     CA  92833-3860
# 802           Long Island Business Institute   Flushing     NY  11354-5577
# 805                         Oikos University    Oakland     CA  94621-2041
# 813       California Institute of Technology   Pasadena     CA       91125
# ...                                      ...        ...    ...         ...
# 6768           Yeshiva Gedolah Keren Hatorah   Lakewood     NJ  08701-1239
# 6774            Yeshiva Gedolah of Cliffwood    Keyport     NJ  07735-5105
# 6780                     Seminary Bnos Chaim   Lakewood     NJ  08701-2336
# 6786       Yeshiva Gedola Tiferes Yerachmiel   Lakewood     NJ  08701-0000
# 6795  EDP University of Puerto Rico-Villalba   Villalba     PR  00766-2353
#
#                                            ACCREDAGENCY  HCM2  \
# ...

# %%
df=df[df.ADM_RATE>0.115]
df.tail()
# Out:
#                                       INSTNM      CITY STABBR         ZIP  \
# 6768           Yeshiva Gedolah Keren Hatorah  Lakewood     NJ  08701-1239
# 6774            Yeshiva Gedolah of Cliffwood   Keyport     NJ  07735-5105
# 6780                     Seminary Bnos Chaim  Lakewood     NJ  08701-2336
# 6786       Yeshiva Gedola Tiferes Yerachmiel  Lakewood     NJ  08701-0000
# 6795  EDP University of Puerto Rico-Villalba  Villalba     PR  00766-2353
#
#                                            ACCREDAGENCY  HCM2  \
# 6768      Association of Institutions of Jewish Studies     0
# 6774  Association of Advanced Rabbinical and Talmudi...     0
# 6780      Association of Institutions of Jewish Studies     0
# 6786      Association of Institutions of Jewish Studies     0
# 6795       Middle States Commission on Higher Education     0
#
#                  MAIN  NUMBRANCH                                    PREDDEG  \
# ...

# %%
df.to_csv('result_College.csv', index=False)
